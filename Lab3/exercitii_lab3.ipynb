# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Ex. 1
# ----> 3 USER_PLAYER, AI_PLAYER = ["Rock", "Paper", "Scissors"]
#       5 def user_input():
#       6     return input("Te rog alege una din cele 3 ('Rock', 'Paper', 'Scissors'): ")
#
# ValueError: too many values to unpack (expected 2)
